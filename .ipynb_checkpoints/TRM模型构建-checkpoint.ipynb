# %% [markdown]
# ## 导入包

# %%
import numpy as np
import time
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GroupKFold, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import SGD
import torch.utils.data as Data
torch.manual_seed(0)
import math
import matplotlib.pyplot as plt
import seaborn as sns

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## 导入数据

# %%
# 导入原数据
data = pd.read_csv('./ETTDataset/ETTh1.csv')
# c_all=pd.Series(data.columns)
data
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...          ...
# 17415  10.904000
# 17416  11.044000
# 17417  10.271000
# 17418   9.778000
# 17419   9.567000
#
# [17420 rows x 8 columns]

# %%
# 导入 归一化数据
data_S = pd.read_csv('./ETTDataset/ETTh1_S.csv')
c_all=pd.Series(data_S.columns.drop('date'))
data_S
# Out:
#                       date      HUFL      HULL      MUFL      MULL      LUFL  \
# 0      2016-07-01 00:00:00  0.615599  0.454943  0.628980  0.467510  0.556576
# 1      2016-07-01 01:00:00  0.612708  0.459449  0.626458  0.464878  0.550279
# 2      2016-07-01 02:00:00  0.601143  0.436920  0.621438  0.459689  0.512595
# 3      2016-07-01 03:00:00  0.599698  0.450437  0.621438  0.462320  0.515693
# 4      2016-07-01 04:00:00  0.605480  0.450437  0.626458  0.467510  0.521990
# ...                    ...       ...       ...       ...       ...       ...
# 17415  2018-06-26 15:00:00  0.453765  0.558574  0.458955  0.589577  0.481107
# 17416  2018-06-26 16:00:00  0.371392  0.608137  0.376064  0.599956  0.487404
# 17417  2018-06-26 17:00:00  0.550572  0.576597  0.572038  0.587018  0.506298
# 17418  2018-06-26 18:00:00  0.689299  0.576597  0.720262  0.587018  0.500000
# 17419  2018-06-26 19:00:00  0.708091  0.558574  0.737019  0.548059  0.506298
#
#            LULL        OT
# 0      0.613765  0.691018
# 1      0.620783  0.636233
# 2      0.586144  0.636233
# 3      0.599955  0.581468
# 4      0.599955  0.519656
# ...         ...       ...
# 17415  0.655196  0.299159
# 17416  0.689608  0.301955
# 17417  0.655196  0.286521
# 17418  0.634594  0.276679
# 17419  0.641386  0.272466
#
# [17420 rows x 8 columns]

# %%
# 这里尝试  用归一化数据来预测未归一化的 标签
features = ["HUFL", "HULL", "MUFL", "MULL","LUFL","LULL"]
data_X = data_S[features]
data_y = data.OT
data_X
# Out:
#            HUFL      HULL      MUFL      MULL      LUFL      LULL
# 0      0.615599  0.454943  0.628980  0.467510  0.556576  0.613765
# 1      0.612708  0.459449  0.626458  0.464878  0.550279  0.620783
# 2      0.601143  0.436920  0.621438  0.459689  0.512595  0.586144
# 3      0.599698  0.450437  0.621438  0.462320  0.515693  0.599955
# 4      0.605480  0.450437  0.626458  0.467510  0.521990  0.599955
# ...         ...       ...       ...       ...       ...       ...
# 17415  0.453765  0.558574  0.458955  0.589577  0.481107  0.655196
# 17416  0.371392  0.608137  0.376064  0.599956  0.487404  0.689608
# 17417  0.550572  0.576597  0.572038  0.587018  0.506298  0.655196
# 17418  0.689299  0.576597  0.720262  0.587018  0.500000  0.634594
# 17419  0.708091  0.558574  0.737019  0.548059  0.506298  0.641386
#
# [17420 rows x 6 columns]

# %%
# 切分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(data_X, data_y, test_size=0.2, shuffle=False)
# 切分训练集和验证集
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, shuffle=False)
X_train, X_val, y_train, y_val
# Out:
# (           HUFL      HULL      MUFL      MULL      LUFL      LULL
#  0      0.615599  0.454943  0.628980  0.467510  0.556576  0.613765
#  1      0.612708  0.459449  0.626458  0.464878  0.550279  0.620783
#  2      0.601143  0.436920  0.621438  0.459689  0.512595  0.586144
#  3      0.599698  0.450437  0.621438  0.462320  0.515693  0.599955
#  4      0.605480  0.450437  0.626458  0.467510  0.521990  0.599955
#  ...         ...       ...       ...       ...       ...       ...
#  10447  0.692190  0.396436  0.732824  0.402602  0.430828  0.558750
#  10448  0.544790  0.405447  0.582927  0.436372  0.449721  0.613765
#  10449  0.473981  0.333356  0.504183  0.374022  0.427731  0.572334
#  10450  0.358382  0.400941  0.376064  0.392150  0.452818  0.586144
#  10451  0.417627  0.382919  0.430484  0.410350  0.446521  0.558750
#
#  [10452 rows x 6 columns],
#             HUFL      HULL      MUFL      MULL      LUFL      LULL
#  10452  0.367055  0.369401  0.377737  0.361012  0.408837  0.613765
#  10453  0.223991  0.504506  0.251267  0.509100  0.418232  0.565542
#  10454  0.291909  0.454943  0.309882  0.470068  0.389944  0.558750
#  10455  0.398835  0.373907  0.428810  0.397412  0.361656  0.524111
#  10456  0.440755  0.319839  0.467345  0.363643  0.396242  0.551732
#  ...         ...       ...       ...       ...       ...       ...
#  13931  0.604035  0.490989  0.615593  0.542797  0.569172  0.517319
#  13932  0.287573  0.527034  0.277216  0.532417  0.496903  0.517319
#  13933  0.524574  0.504506  0.536850  0.550618  0.547181  0.572334
#  13934  0.328026  0.527034  0.324118  0.535049  0.493702  0.579352
#  13935  0.618490  0.518023  0.625633  0.542797  0.531489  0.558750
#
#  [3484 rows x 6 columns],
#  0        30.531000
#  1        27.787001
#  2        27.787001
#  3        25.044001
#  4        21.948000
#             ...
#  10447    13.929000
#  10448    14.984000
#  10449    15.054000
#  10450    16.250000
#  10451    15.547000
#  Name: OT, Length: 10452, dtype: float64,
#  10452    16.108999
#  10453    16.250000
#  10454    17.305000
#  10455    17.094000
#  10456    17.375999
#             ...
#  13931     4.713000
#  13932     4.291000
#  13933     4.291000
#  13934     6.261000
#  13935     3.939000
#  Name: OT, Length: 3484, dtype: float64)

# %%
# 将数据集转为张量,对象类型为tensor

X_train_t = torch.from_numpy(X_train.values.astype(np.float32))  # 加上.values可进行转化
y_train_t = torch.from_numpy(y_train.values.astype(np.float32))

X_val_t = torch.from_numpy(X_val.values.astype(np.float32))
y_val_t = torch.from_numpy(y_val.values.astype(np.float32))

X_test_t = torch.from_numpy(X_test.values.astype(np.float32))
y_test_t = torch.from_numpy(y_test.values.astype(np.float32))
X_train_t.shape
# y_train_t
# Out:
# torch.Size([10452, 6])

# %%
y_train_t.shape
# Out:
# torch.Size([10452])

# %%
X_test_t.shape
# Out:
# torch.Size([3484, 6])

# %%
# 将训练数据处理为数据加载器
## 将训练集转化为张量后，使用TensorDataset将x y整理到一块
train_data = Data.TensorDataset(X_train_t, y_train_t)
val_data = Data.TensorDataset(X_val_t, y_val_t,)
test_data = Data.TensorDataset(X_test_t, y_test_t,)

train_loader = Data.DataLoader(dataset = train_data, 
                               batch_size = 64, # 批处理样本大小
                               shuffle = False,  
                               num_workers = 0) # 使用一个进程

val_loader = Data.DataLoader(dataset = val_data, 
                               batch_size = 64, # 批处理样本大小
                               shuffle = False,  
                               num_workers = 0) # 使用一个进程

# %% [markdown]
# ## 构建模型

# %% [markdown]
# ### Autoformer

# %%
#### positional encoding ####
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()       
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        #pe.requires_grad = False
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]
       
        
#### model stracture ####
class TransAm(nn.Module):
    def __init__(self,feature_size=250,num_layers=1,dropout=0.1):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'
        
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)        
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.pos_encoder(src)
        output = self.transformer_encoder(src,self.src_mask)#, self.src_mask)
        output = self.decoder(output)
        return output

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

# %%
# data
# if window is 100 and prediction step is 1
# in -> [0..99]
# target -> [1..100]
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = np.append(input_data[i:i+tw][:-output_window] , output_window * [0])
        train_label = input_data[i:i+tw]
        #train_label = input_data[i+output_window:i+tw+output_window]
        inout_seq.append((train_seq ,train_label))
    return torch.FloatTensor(inout_seq)

# %%
def get_data():
    time        = np.arange(0, 400, 0.1)
    amplitude   = np.sin(time) + np.sin(time*0.05) +np.sin(time*0.12) *np.random.normal(-0.2, 0.2, len(time))
    
    #from pandas import read_csv
    #series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
    
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(feature_range=(-1, 1)) 
    #amplitude = scaler.fit_transform(series.to_numpy().reshape(-1, 1)).reshape(-1)
    amplitude = scaler.fit_transform(amplitude.reshape(-1, 1)).reshape(-1)
    
    
    sampels = 2800
    train_data = amplitude[:sampels]
    test_data = amplitude[sampels:]

    # convert our train data into a pytorch train tensor
    #train_tensor = torch.FloatTensor(train_data).view(-1)
    # todo: add comment.. 
    train_sequence = create_inout_sequences(train_data,input_window)
    train_sequence = train_sequence[:-output_window] #todo: fix hack?

    #test_data = torch.FloatTensor(test_data).view(-1) 
    test_data = create_inout_sequences(test_data,input_window)
    test_data = test_data[:-output_window] #todo: fix hack?

    return train_sequence.to(device),test_data.to(device)

def get_batch(source, i,batch_size):
    seq_len = min(batch_size, len(source) - 1 - i)
    data = source[i:i+seq_len]    
    input = torch.stack(torch.stack([item[0] for item in data]).chunk(input_window,1)) # 1 is feature size
    target = torch.stack(torch.stack([item[1] for item in data]).chunk(input_window,1))
    return input, target

# %%
#### 定义训练函数 ####
def train(train_data):
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()

    for batch, i in enumerate(range(0, len(train_data) - 1, batch_size)):
        data, targets = get_batch(train_data, i,batch_size)
        optimizer.zero_grad()
        output = model(data)        

        if calculate_loss_over_all_values:
            loss = criterion(output, targets)
        else:
            loss = criterion(output[-output_window:], targets[-output_window:])
    
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_data) / batch_size / 5)
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.6f} | {:5.2f} ms | '
                  'loss {:5.5f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // batch_size, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
#### 训练过程可视化 ####
def plot_and_loss(eval_model, data_source,epoch):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    with torch.no_grad():
        for i in range(0, len(data_source) - 1):
            data, target = get_batch(data_source, i,1)
            # look like the model returns static values for the output window
            output = eval_model(data)    
            if calculate_loss_over_all_values:                                
                total_loss += criterion(output, target).item()
            else:
                total_loss += criterion(output[-output_window:], target[-output_window:]).item()
            
            test_result = torch.cat((test_result, output[-1].view(-1).cpu()), 0) #todo: check this. -> looks good to me
            truth = torch.cat((truth, target[-1].view(-1).cpu()), 0)
            
    #test_result = test_result.cpu().numpy()
    len(test_result)

    pyplot.plot(test_result,color="red")
    pyplot.plot(truth[:500],color="blue")
    pyplot.plot(test_result-truth,color="green")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.savefig('graph/transformer-epoch%d.png'%epoch)
    pyplot.close()
    
    return total_loss / i

# %%
def predict_future(eval_model, data_source,steps):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    _ , data = get_batch(data_source, 0,1)
    with torch.no_grad():
        for i in range(0, steps,1):
            input = torch.clone(data[-input_window:])
            input[-output_window:] = 0     
            output = eval_model(data[-input_window:])                        
            data = torch.cat((data, output[-1:]))
            
    data = data.cpu().view(-1)
    

    pyplot.plot(data,color="red")       
    pyplot.plot(data[:input_window],color="blue")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.savefig('graph/transformer-future%d.png'%steps)
    pyplot.close()
        
# entweder ist hier ein fehler im loss oder in der train methode, aber die ergebnisse sind unterschiedlich 
# auch zu denen der predict_future

#### 定义测试函数 ####
def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    eval_batch_size = 1000
    with torch.no_grad():
        for i in range(0, len(data_source) - 1, eval_batch_size):
            data, targets = get_batch(data_source, i,eval_batch_size)
            output = eval_model(data)            
            if calculate_loss_over_all_values:
                total_loss += len(data[0])* criterion(output, targets).cpu().item()
            else:                                
                total_loss += len(data[0])* criterion(output[-output_window:], targets[-output_window:]).cpu().item()            
    return total_loss / len(data_source)

# %%
#### 训练测试模型 ####
train_data, val_data = get_data()
model = TransAm().to(device)

criterion = nn.MSELoss()
lr = 0.005 
#optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.98)

best_val_loss = float("inf")
epochs = 100 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(train_data)
    
    
    if(epoch % 10 is 0):
        val_loss = plot_and_loss(model, val_data,epoch)
        predict_future(model, val_data,200)
    else:
        val_loss = evaluate(model, val_data)
        
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.5f} | valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    #if val_loss < best_val_loss:
    #    best_val_loss = val_loss
    #    best_model = model

    scheduler.step() 

#src = torch.rand(input_window, batch_size, 1) # (source sequence length,batch size,feature number) 
#out = model(src)
#
#print(out)
#print(out.shape)

# %% [markdown]
# #### 训练

# %%
# batch_size
batch_size = 64 # 前面取数据batch_size = 64 记得也更改
lr = 0.05
# 定义优化器
optimizer = torch.optim.SGD(MLP.parameters(), lr = lr)
loss_func = nn.MSELoss() # 最小均方根误差损失函数
train_loss_all = [] # 输出每个批次训练的损失函数  后续可用于绘制图

# 对模型迭代训练，总共epoch轮
for epoch in range(100):
    train_loss = 0
    train_num = 0
    
    # 对训练数据的加载器进行迭代计算
    for step, (b_x, b_y) in enumerate(train_loader):
        b_x = b_x.to(device)
        b_y = b_y.to(device)
#         print(b_x.shape)
#         print(b_y.shape)
        start_time = time.time()
        output = MLP(b_x)#.flatten() # MLP在训练batch上的输出
        loss = loss_func(output, b_y) # 均方根损失函数
        
        optimizer.zero_grad() # 每次迭代梯度初始化0
        loss.backward() # 反向传播，计算梯度
        optimizer.step() # 使用梯度进行优化
        train_loss += loss.item() * b_x.size(0)
        train_num += b_x.size(0)
        log_interval = int(len(train_data) / batch_size / 4)

        if step % log_interval == 0 and step > 0:
            elapsed = time.time() - start_time
            print('| epoch {:4d} | {:5d}/{:5d} batches | {:5.2f} ms | loss {:5.5f} '
                  .format(epoch, step, len(train_data) // batch_size, elapsed * 1000 / log_interval, train_loss / train_num))
        
    train_loss_all.append(train_loss / train_num) # 计算一个epoch在训练集上的损失
#     print(train_loss_all)
#     print('epoch= %03d, loss= %.4f'
#               % (epoch + 1, train_loss / train_num))
# Out:
# | epoch    0 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    0 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch    0 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    0 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    1 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    1 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    1 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    1 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    2 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    2 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    2 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    2 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    3 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    3 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    3 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    3 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    4 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    4 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    4 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    4 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    5 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    5 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    5 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    5 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    6 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    6 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    6 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    6 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    7 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    7 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    7 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    7 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    8 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    8 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    8 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    8 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch    9 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch    9 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch    9 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch    9 |   188/  190 batches |  0.05 ms | loss   nan
# | epoch   10 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   10 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   10 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   10 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   11 |    47/  190 batches |  0.07 ms | loss   nan
# | epoch   11 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   11 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   11 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   12 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   12 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   12 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   12 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   13 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   13 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   13 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   13 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   14 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   14 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   14 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   14 |   188/  190 batches |  0.05 ms | loss   nan
# | epoch   15 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   15 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   15 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   15 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   16 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   16 |    94/  190 batches |  0.05 ms | loss   nan
# | epoch   16 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   16 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   17 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   17 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   17 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   17 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   18 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   18 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   18 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   18 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   19 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   19 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   19 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   19 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   20 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   20 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   20 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   20 |   188/  190 batches |  0.13 ms | loss   nan
# | epoch   21 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   21 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   21 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   21 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   22 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   22 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   22 |   141/  190 batches |  0.05 ms | loss   nan
# | epoch   22 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   23 |    47/  190 batches |  0.05 ms | loss   nan
# | epoch   23 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   23 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   23 |   188/  190 batches |  0.09 ms | loss   nan
# | epoch   24 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   24 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   24 |   141/  190 batches |  0.11 ms | loss   nan
# | epoch   24 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   25 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   25 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   25 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   25 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   26 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   26 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   26 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   26 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   27 |    47/  190 batches |  0.11 ms | loss   nan
# | epoch   27 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   27 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   27 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   28 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   28 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   28 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   28 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   29 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   29 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   29 |   141/  190 batches |  0.09 ms | loss   nan
# | epoch   29 |   188/  190 batches |  0.13 ms | loss   nan
# | epoch   30 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   30 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   30 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   30 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   31 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   31 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   31 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   31 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   32 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   32 |    94/  190 batches |  0.11 ms | loss   nan
# | epoch   32 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   32 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   33 |    47/  190 batches |  0.09 ms | loss   nan
# | epoch   33 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   33 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   33 |   188/  190 batches |  0.11 ms | loss   nan
# | epoch   34 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   34 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   34 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   34 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   35 |    47/  190 batches |  0.09 ms | loss   nan
# | epoch   35 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   35 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   35 |   188/  190 batches |  0.13 ms | loss   nan
# | epoch   36 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   36 |    94/  190 batches |  0.11 ms | loss   nan
# | epoch   36 |   141/  190 batches |  0.25 ms | loss   nan
# | epoch   36 |   188/  190 batches |  0.11 ms | loss   nan
# | epoch   37 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   37 |    94/  190 batches |  0.19 ms | loss   nan
# | epoch   37 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   37 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   38 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   38 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   38 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   38 |   188/  190 batches |  0.13 ms | loss   nan
# | epoch   39 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   39 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   39 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   39 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   40 |    47/  190 batches |  0.13 ms | loss   nan
# | epoch   40 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   40 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   40 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   41 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   41 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   41 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   41 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   42 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   42 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   42 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   42 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   43 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   43 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   43 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   43 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   44 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   44 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   44 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   44 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   45 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   45 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   45 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   45 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   46 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   46 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   46 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   46 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   47 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   47 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   47 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   47 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   48 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   48 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   48 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   48 |   188/  190 batches |  0.05 ms | loss   nan
# | epoch   49 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   49 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   49 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   49 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   50 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   50 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   50 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   50 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   51 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   51 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   51 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   51 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   52 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   52 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   52 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   52 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   53 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   53 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   53 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   53 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   54 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   54 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   54 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   54 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   55 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   55 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   55 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   55 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   56 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   56 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   56 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   56 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   57 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   57 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   57 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   57 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   58 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   58 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   58 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   58 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   59 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   59 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   59 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   59 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   60 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   60 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   60 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   60 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   61 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   61 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   61 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   61 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   62 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   62 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   62 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   62 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   63 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   63 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   63 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   63 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   64 |    47/  190 batches |  0.13 ms | loss   nan
# | epoch   64 |    94/  190 batches |  0.09 ms | loss   nan
# | epoch   64 |   141/  190 batches |  0.08 ms | loss   nan
# | epoch   64 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   65 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   65 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   65 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   65 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   66 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   66 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   66 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   66 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   67 |    47/  190 batches |  0.08 ms | loss   nan
# | epoch   67 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   67 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   67 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   68 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   68 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   68 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   68 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   69 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   69 |    94/  190 batches |  0.08 ms | loss   nan
# | epoch   69 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   69 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   70 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   70 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   70 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   70 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   71 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   71 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   71 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   71 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   72 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   72 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   72 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   72 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   73 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   73 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   73 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   73 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   74 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   74 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   74 |   141/  190 batches |  0.09 ms | loss   nan
# | epoch   74 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   75 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   75 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   75 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   75 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   76 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   76 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   76 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   76 |   188/  190 batches |  0.08 ms | loss   nan
# | epoch   77 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   77 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   77 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   77 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   78 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   78 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   78 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   78 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   79 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   79 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   79 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   79 |   188/  190 batches |  0.05 ms | loss   nan
# | epoch   80 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   80 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   80 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   80 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   81 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   81 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   81 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   81 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   82 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   82 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   82 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   82 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   83 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   83 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   83 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   83 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   84 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   84 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   84 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   84 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   85 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   85 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   85 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   85 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   86 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   86 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   86 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   86 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   87 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   87 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   87 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   87 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   88 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   88 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   88 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   88 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   89 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   89 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   89 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   89 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   90 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   90 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   90 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   90 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   91 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   91 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   91 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   91 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   92 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   92 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   92 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   92 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   93 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   93 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   93 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   93 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   94 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   94 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   94 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   94 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   95 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   95 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   95 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   95 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   96 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   96 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   96 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   96 |   188/  190 batches |  0.06 ms | loss   nan
# | epoch   97 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   97 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   97 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   97 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   98 |    47/  190 batches |  0.06 ms | loss   nan
# | epoch   98 |    94/  190 batches |  0.06 ms | loss   nan
# | epoch   98 |   141/  190 batches |  0.04 ms | loss   nan
# | epoch   98 |   188/  190 batches |  0.04 ms | loss   nan
# | epoch   99 |    47/  190 batches |  0.04 ms | loss   nan
# | epoch   99 |    94/  190 batches |  0.04 ms | loss   nan
# | epoch   99 |   141/  190 batches |  0.06 ms | loss   nan
# | epoch   99 |   188/  190 batches |  0.06 ms | loss   nan

# %%
# 测试验证集：用测试集部分作为验证集
# 测试 MSE 用法
from tqdm import tqdm
batch_size = 64
epoch  = 1#这里是训练的轮数
learning = 0.01 #学习率
optimizer = torch.optim.SGD(MLP.parameters(), lr = learning)#优化器
los = nn.MSELoss()#损失函数
train_loss_all = [] # 输出每个批次训练的损失函数  后续可用于绘制图

fit_rate=0
for epoch in range(50):
    train_loss = 0
    train_num = 0
    
    # 对训练数据的加载器进行迭代计算
#     train_bar = tqdm(train_loader)  #显示进度条
    for step, (b_x, b_y) in enumerate(train_loader):
        b_x = b_x.to(device)
        b_y = b_y.to(device)
#         print(b_x.shape)
#         print(b_y.shape)
        start_time = time.time()
        output = MLP(b_x)#.flatten() # MLP在训练batch上的输出
#         MSE
        loss = nn.MSELoss()(output, b_y) # 均方根损失函数
        optimizer.zero_grad() # 每次迭代梯度初始化0
        loss.backward() # 反向传播，计算梯度
        optimizer.step() # 使用梯度进行优化
        train_loss += loss.item() * b_x.size(0)
        train_num += b_x.size(0)
        log_interval = int(len(train_data) / batch_size / 4)

        if step % log_interval == 0 and step > 0:
#             这里进行评估验证
            fitted = 0
            total = 0
            for (b_x, b_y) in valid_loader:
                b_x = b_x.to(device)
                b_y = b_y.to(device)
                outputs = MLP(b_x)
                loss2 = nn.MSELoss()(outputs, b_y)
                fitted += loss2.item()* b_x.size(0)
                total +=b_x.size(0)
            fit_rate = 100.*fitted/total
            elapsed = time.time() - start_time
            print('| epoch {:4d} | {:5d}/{:5d} batches | {:5.2f} ms | loss {:5.5f} | Fit_rate {}%'
                  .format(epoch, step, len(train_data) // batch_size, elapsed * 1000 / log_interval, train_loss / train_num, fit_rate))
        
    train_loss_all.append(train_loss / train_num) # 计算一个epoch在训练集上的损失
# Out:
# | epoch    0 |    47/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    0 |    94/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    0 |   141/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    0 |   188/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    1 |    47/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    1 |    94/  190 batches |  0.15 ms | loss   nan | Fit_rate nan%
# | epoch    1 |   141/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    1 |   188/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    2 |    47/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    2 |    94/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    2 |   141/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    2 |   188/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    3 |    47/  190 batches |  0.12 ms | loss   nan | Fit_rate nan%
# | epoch    3 |    94/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    3 |   141/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    3 |   188/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    4 |    47/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    4 |    94/  190 batches |  0.15 ms | loss   nan | Fit_rate nan%
# | epoch    4 |   141/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    4 |   188/  190 batches |  0.13 ms | loss   nan | Fit_rate nan%
# | epoch    5 |    47/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# | epoch    5 |    94/  190 batches |  0.11 ms | loss   nan | Fit_rate nan%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2432/4138862948.py in <module>
#      22 #         print(b_y.shape)
#      23         start_time = time.time()
# ---> 24         output = MLP(b_x)#.flatten() # MLP在训练batch上的输出
#      25 #         MSE
#      26         loss = nn.MSELoss()(output, b_y) # 均方根损失函数
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Temp/ipykernel_2432/4141121747.py in forward(self, x)
#      20     # 定义网络前向传播路径
#      21     def forward(self, x):
# ---> 22         x = self.hidden(x)
#      23         output = self.regression(x)
#      24         # 输出一个一维向量
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
# 保存模型
PATH = './models/MLP_unscale.pth'
torch.save(MLP, PATH)
# _1 三层100
# _2 三层200
# _3 三层512
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13288/1059995024.py in <module>
#       1 # 保存模型
#       2 PATH = './models/MLP_unscale.pth'
# ----> 3 torch.save(MLP, PATH)
#       4 # _1 三层100
#       5 # _2 三层200
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     373                 return
#     374         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     474     pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     475     pickler.persistent_id = persistent_id
# --> 476     pickler.dump(obj)
#     477     data_value = data_buf.getvalue()
#     478     zip_file.write_record('data.pkl', data_value, len(data_value))
#
# PicklingError: Can't pickle <class '__main__.MLPregression'>: it's not the same object as __main__.MLPregression

# %%
# 另一种保存模型方法——保存与加载整个state_dict
PATHH = "./models/MLP_unscale_sd.pth"
# _3 三层300

torch.save(MLP.state_dict(), PATHH)

# %%
# 可视化损失函数的变换情况
plt.figure(figsize = (8, 6))
plt.plot(train_loss_all, 'ro-', label = 'Train loss')
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title("Train loss per iteration")
plt.show()

# %%
output
# Out:
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        device='cuda:0', grad_fn=<SelectBackward>)

# %%
b_y = b_y.data.cpu().numpy()
output = output.data.cpu().numpy()
output
# Out:
# array([ 3.0563946,  3.5117893,  2.9845705, 14.457432 ,  7.5310435,
#         9.703519 ,  7.141563 , 11.309269 ,  6.1407995,  5.2774143,
#        13.888754 ,  2.463294 , 17.31658  ,  3.8494558, 12.9851465,
#        10.919244 , 24.520142 , 15.877787 , 12.653085 , 29.827623 ,
#        12.733791 , 13.652879 ,  1.999444 ,  8.791749 , 15.145212 ,
#         5.3395166, 21.14603  ,  2.3346624, 13.245804 , 18.767616 ,
#        18.657875 , 19.41424  , 20.126396 ,  8.715624 ], dtype=float32)

# %%
# 可视化查看效果
# index = np.argsort(b_y)
plt.figure(figsize=(8, 6))
plt.plot(np.arange(len(b_y)), b_y, 'r', label = 'Original Y')
plt.scatter(np.arange(len(output)), output, s = 3, c = 'b', label = 'TrainPrediction')
plt.legend(loc = 'upper left')
plt.grid()
plt.xlabel('Index')
plt.ylabel('Y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2432/2486988150.py in <module>
#       2 # index = np.argsort(b_y)
#       3 plt.figure(figsize=(8, 6))
# ----> 4 plt.plot(np.arange(len(b_y)), b_y, 'r', label = 'Original Y')
#       5 plt.scatter(np.arange(len(output)), output, s = 3, c = 'b', label = 'TrainPrediction')
#       6 plt.legend(loc = 'upper left')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
# -> 2771         **({"data": data} if data is not None else {}), **kwargs)
#    2772
#    2773
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
# -> 1634             self.add_line(line)
#    1635         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636         return lines
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    2286             line.set_clip_path(self.patch)
#    2287
# -> 2288         self._update_line_limits(line)
#    2289         if not line.get_label():
#    2290             line.set_label(f'_child{len(self._children)}')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    2309         Figures out the data limit of the given line, updating self.dataLim.
#    2310         """
# -> 2311         path = line.get_path()
#    2312         if path.vertices.size == 0:
#    2313             return
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\lines.py in get_path(self)
#     997         """Return the `~matplotlib.path.Path` associated with this line."""
#     998         if self._invalidy or self._invalidx:
# --> 999             self.recache()
#    1000         return self._path
#    1001
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\lines.py in recache(self, always)
#     655         if always or self._invalidy:
#     656             yconv = self.convert_yunits(self._yorig)
# --> 657             y = _to_unmasked_float_array(yconv).ravel()
#     658         else:
#     659             y = self._y
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1296         return np.ma.asarray(x, float).filled(np.nan)
#    1297     else:
# -> 1298         return np.asarray(x, float)
#    1299
#    1300
#
# D:\Anaconda\envs\xai\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\tensor.py in __array__(self, dtype)
#     630             return self.numpy()
#     631         else:
# --> 632             return self.numpy().astype(dtype, copy=False)
#     633
#     634     # Wrap Numpy array again in a suitable tensor when done, to support e.g.
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %% [markdown]
# #### 测试

# %%
# model_un = MLPregression().to(device)
# PATH = './models/MLP_unscale_sd.pth'
# model_un.load_state_dict(torch.load(PATH))

# %%
# 引入模型架构后引入模型
model_un = MLPregression().to(device)
PATH = './models/MLP_unscale_sd.pth'
model_un.load_state_dict(torch.load(PATH))
model_un.eval()

X_test_t = X_test_t.to(device)
y_pre = model_un(X_test_t)
y_pre = y_pre.data.cpu().numpy()
# 更换为 mean_squared_error
mse = mean_squared_error(y_test, y_pre)
print('在测试集上的均方根误差为:', mse)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2432/3291037631.py in <module>
#       2 model_un = MLPregression().to(device)
#       3 PATH = './models/MLP_unscale_sd.pth'
# ----> 4 model_un.load_state_dict(torch.load(PATH))
#       5 model_un.eval()
#       6
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1050         if len(error_msgs) > 0:
#    1051             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1052                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1053         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1054
#
# RuntimeError: Error(s) in loading state_dict for MLPregression:
# 	size mismatch for hidden.0.weight: copying a param with shape torch.Size([300, 6]) from checkpoint, the shape in current model is torch.Size([1024, 6]).
# 	size mismatch for hidden.0.bias: copying a param with shape torch.Size([300]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for hidden.2.weight: copying a param with shape torch.Size([300, 300]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for hidden.2.bias: copying a param with shape torch.Size([300]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for hidden.4.weight: copying a param with shape torch.Size([300, 300]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for hidden.4.bias: copying a param with shape torch.Size([300]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for regression.weight: copying a param with shape torch.Size([1, 300]) from checkpoint, the shape in current model is torch.Size([1, 1024]).

# %%
# 直接用测试 数据测试
# model = MLP
state_dict = torch.load('./models/MLP_unscale_sd.pth')
model.load_state_dict(state_dict)


X_test_t = X_test_t.to(device)
y_pre = MLP(X_test_t)
y_pre = y_pre.data.cpu().numpy()
mae = mean_squared_error(y_test, y_pre)
print(y_pre)
print('在测试集上的均方误差为:', mse)
# Out:
# [13.151983  14.244891  21.062767  ...  2.1454697 17.95219   12.225722 ]
# 在测试集上的均方误差为: 256.96078050555195

# %%
# 均方根误差
# test测试
# 引入模型进行测试
# 搭建全连接神经网络回归--使用nn.Sequential的形式
features = ["HUFL", "HULL", "MUFL", "MULL","LUFL","LULL"]
hid_dim = 300
class MLPregression(nn.Module):  # 定义全连接神经网络
    def __init__(self):
        # 初始化：子类继承了父类的所有属性和方法，父类属性自然会用父类方法来进行初始化
        super(MLPregression, self).__init__()
        # 定义隐藏层
        self.hidden = nn.Sequential(
            nn.Linear(len(features), hid_dim),
            nn.ReLU(),
            nn.Linear(hid_dim, hid_dim),
            nn.ReLU(),
            nn.Linear(hid_dim, hid_dim),
            nn.ReLU(),
        )
        # 预测回归层
        self.regression = nn.Linear(hid_dim, 1)

        
    # 定义网络前向传播路径
    def forward(self, x):
        x = self.hidden(x)
        output = self.regression(x)
        # 输出一个一维向量
        return output[:, 0]
    
    
# 引入模型架构后引入模型
model_3 = MLPregression().to(device)
PATH = './models/MLP_unscale_sd.pth'
model_3.load_state_dict(torch.load(PATH))
model_3.eval()

X_train_t = X_train_t.to(device)
y_pre = model_3(X_train_t)
y_pre = y_pre.data.cpu().numpy()
# 更换为 mean_squared_error
mse = mean_squared_error(y_train, y_pre)
print('在测试集上的均方根误差为:', mse)
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13288/1764944589.py in <module>
#      33 model_3 = MLPregression().to(device)
#      34 PATH = './models/MLP_unscale.pth'
# ---> 35 model_3.load_state_dict(torch.load(PATH))
#      36 model_3.eval()
#      37
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1023         # copy state_dict so _load_from_state_dict can modify it
#    1024         metadata = getattr(state_dict, '_metadata', None)
# -> 1025         state_dict = state_dict.copy()
#    1026         if metadata is not None:
#    1027             state_dict._metadata = metadata
#
# D:\Anaconda\envs\xai\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'MLPregression' object has no attribute 'copy'

# %% [markdown]
# #### 绘图归一化或未归一化 数据分析

# %%
# 对于 shuffle 的结果，从第一列到最后一列，每一列挨个进行随机扰动，控制变量法，保证，每次进行训练时，只有一列进行了扰动
seed = 2020
x = X_train

# sample 函数附加随机性质, sample会改变原来的数组
# replace: 是否允许重复抽样，默认情况下为False

for i in range(x.shape[1]):
    x.iloc[:,i] = x.iloc[:,i].sample(x.shape[0], replace=False, random_state=seed+5).values
    
    print(x.iloc[:,i])
print(x)
# Out:
# 5430     0.505761
# 4469     0.488414
# 14858    0.332384
# 10076    0.268781
# 2579     0.257217
#            ...
# 6384     0.491305
# 14001    0.315038
# 4720    -0.011564
# 16557    0.606947
# 1244     0.320820
# Name: HUFL, Length: 12194, dtype: float64
# 5430    -0.189106
# 4469     0.261332
# 14858   -0.225151
# 10076   -0.621520
# 2579    -0.441426
#            ...
# 6384     0.378346
# 14001   -0.063080
# 4720    -0.405380
# 16557   -0.027034
# 1244    -0.612508
# Name: HULL, Length: 12194, dtype: float64
# 5430     0.564496
# 4469     0.613048
# 14858    0.417097
# 10076    0.385279
# 2579     0.350067
#            ...
# 6384     0.644913
# 14001    0.402013
# 4720     0.100521
# 16557    0.626482
# 1244     0.438874
# Name: MUFL, Length: 12194, dtype: float64
# 5430    -0.163658
# 4469     0.236313
# 14858   -0.137782
# 10076   -0.553249
# 2579    -0.428551
#            ...
# 6384     0.355749
# 14001   -0.054601
# 4720    -0.319494
# 16557   -0.013084
# 1244    -0.532490
# Name: MULL, Length: 12194, dtype: float64
# 5430     0.069172
# 4469    -0.352261
# 14858   -0.094363
# 10076   -0.264093
# 2579    -0.188726
#            ...
# 6384    -0.383647
# 14001   -0.132149
# 4720    -0.289284
# 16557    0.301879
# 1244    -0.251497
# Name: LUFL, Length: 12194, dtype: float64
# 5430     0.062259
# 4469    -0.131084
# 14858   -0.048223
# 10076   -0.007018
# 2579     0.103464
#            ...
# 6384     0.034639
# 14001    0.158705
# 4720     0.103464
# 16557    0.075843
# 1244    -0.186326
# Name: LULL, Length: 12194, dtype: float64
#            HUFL      HULL      MUFL      MULL      LUFL      LULL
# 5430   0.505761 -0.189106  0.564496 -0.163658  0.069172  0.062259
# 4469   0.488414  0.261332  0.613048  0.236313 -0.352261 -0.131084
# 14858  0.332384 -0.225151  0.417097 -0.137782 -0.094363 -0.048223
# 10076  0.268781 -0.621520  0.385279 -0.553249 -0.264093 -0.007018
# 2579   0.257217 -0.441426  0.350067 -0.428551 -0.188726  0.103464
# ...         ...       ...       ...       ...       ...       ...
# 6384   0.491305  0.378346  0.644913  0.355749 -0.383647  0.034639
# 14001  0.315038 -0.063080  0.402013 -0.054601 -0.132149  0.158705
# 4720  -0.011564 -0.405380  0.100521 -0.319494 -0.289284  0.103464
# 16557  0.606947 -0.027034  0.626482 -0.013084  0.301879  0.075843
# 1244   0.320820 -0.612508  0.438874 -0.532490 -0.251497 -0.186326
#
# [12194 rows x 6 columns]

# %%
# 训练集 shuffle 测试

# X_train_t
# X_train_t = X_train_t.to(device)

x = X_train
# convert back to tensor, 
x = torch.from_numpy(x.values.astype(np.float32)).to(device)

y_pre = model_3(x)
y_pre = y_pre.data.cpu().numpy()
# 更换为 mean_squared_error
# y_train
mse = mean_squared_error(y_train, y_pre)
print('在训练集上的均方根误差为:', mse)
# Out:
# 在训练集上的均方根误差为: 0.15703322485890575

# %%
X_test_t = X_test_t.to(device)
y_pre = MLP(X_test_t)
y_pre = y_pre.data.cpu().numpy()
mae = mean_absolute_error(y_test, y_pre)
print(y_pre)
print('在测试集上的绝对值误差为:', mae)
# Out:
# [-0.47137207 -0.29620624 -0.20990306 ... -0.72127604 -0.24145916
#  -0.18957923]
# 在测试集上的绝对值误差为: 0.2184597281205516

# %%
# 测试另一种模型
model = MLP
state_dict = torch.load('./models/MLP_3.pth')
model.load_state_dict(state_dict)

y_pre = model(X_test_t)
y_pre = y_pre.data.cpu().numpy()
mae = mean_absolute_error(y_test, y_pre)
print('在测试集上的绝对值误差为:', mae)
# Out:
# 在测试集上的绝对值误差为: 0.19376074133679708

# %%
np.arange(len(y_test))
# Out:
# array([   0,    1,    2, ..., 5223, 5224, 5225])

# %%
y_test.iloc[index]
# Out:
# 3823    -0.997205
# 3822    -0.997205
# 13809   -0.985944
# 13810   -0.971929
# 13765   -0.957873
#            ...
# 594      0.907281
# 567      0.926967
# 711      0.955038
# 665      0.957873
# 687      1.000000
# Name: OT, Length: 5226, dtype: float64

# %%
# 可视化查看效果
# np.argsort(y_test) 将矩阵按照axis排序，并返回排序后的下标--排序让数值更好绘制
index = np.argsort(y_test)
plt.figure(figsize=(16, 9))
# plt.plot(np.arange(len(y_test)), y_test.iloc[index], 'r', label = 'Original Y')
# 上述 index 方法已不能用，改用散点图
plt.scatter(np.arange(len(y_test)), y_test, s = 3, c = 'r', label = 'Original Y')
plt.scatter(np.arange(len(y_pre)), y_pre, s = 3, c = 'b', label = 'Prediction')
plt.legend(loc = 'upper left')
plt.grid()
plt.xlabel('Index')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ### 特征重要性分析

# %%
import eli5
from eli5.sklearn import PermutationImportance
# perm=PermutationImportance(model,random_state=1).fit(X_test,y_test)
# eli5.show_weights(perm,feature_names=X_test.columns.to_list())

# %%
eli5.show_weights(MLP, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator MLPregression(
#   (hidden): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=50, bias=True)
#     (5): ReLU()
#   )
#   (regression): Linear(in_features=50, out_features=1, bias=True)
# ) is not supported
#     </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(df3.data, df3.target,
                                                    test_size = 0.3, random_state = 42)

# %% [markdown]
# 尝试进行特征重要性分析

# %%
from tqdm.notebook import tqdm

# %%
COLS = list(df3data.columns)
print('Number of feature columns =', len(COLS) )
# Out:
# Number of feature columns = 6

# %%
COMPUTE_IMPORTANCE = 1
ONE_FOLD_ONLY = 1
# 特征数量
NUM_FOLDS = 6
# 对df3 数据进行重新切分
kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=2021)
test_preds = []
  # K折交叉验证模型评估
for fold, (train_idx, test_idx) in enumerate(kf.split(df3data, df3target)):
#     K.clear_session()

    print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
    X_train, X_valid = df3data[train_idx], df3data[test_idx]
    y_train, y_valid = df3data[train_idx], df3data[test_idx]

    # 导入已经训练好的模型
    model = keras.models.load_model('./models/MLPregression_1.pth')
    # 计算特征重要性
    if COMPUTE_IMPORTANCE:
        results = []
        print(' Computing model feature importance...')

#         for k in tqdm(range(len(COLS))):
#             if k>0: 
#                 save_col = X_valid[:,:,k-1].copy()
#                 np.random.shuffle(X_valid[:,:,k-1])

#             oof_preds = model.predict(X_valid, verbose=0).squeeze() 
#             mae = np.mean(np.abs( oof_preds-y_valid ))
#             results.append({'feature':COLS[k],'mae':mae})

#             if k>0: 
#                 X_valid[:,:,k-1] = save_col


        # COMPUTE BASELINE (NO SHUFFLE)
        oof_preds = model.predict(X_valid, verbose=0).squeeze() 
        baseline_mae = np.mean(np.abs( oof_preds-y_valid ))
        results.append({'feature':'BASELINE','mae':baseline_mae})           

        for k in tqdm(range(len(COLS))):

            # SHUFFLE FEATURE K
            save_col = X_valid[:,:,k].copy()
            np.random.shuffle(X_valid[:,:,k])

            # COMPUTE OOF MAE WITH FEATURE K SHUFFLED
            oof_preds = model.predict(X_valid, verbose=0).squeeze() 
            mae = np.mean(np.abs( oof_preds-y_valid ))
            results.append({'feature':COLS[k],'mae':mae})
            X_valid[:,:,k] = save_col


        # 展示特征重要性
        print()
        df = pd.DataFrame(results)
        df = df.sort_values('mae')
        plt.figure(figsize=(10,20))
        plt.barh(np.arange(len(COLS)),df.mae)
        plt.yticks(np.arange(len(COLS)),df.feature.values)
        plt.title('LSTM Feature Importance',size=16)
        plt.ylim((-1,len(COLS)))
        plt.show()

        # 保存模型特征重要性
        df = df.sort_values('mae',ascending=False)
        df.to_csv(f'lstm_feature_importance_fold_{fold}.csv',index=False)

    # ONLY DO ONE FOLD
    if ONE_FOLD_ONLY: break
# Out:
# --------------- > Fold 1 < ---------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48592/736070669.py in <module>
#      11
#      12     print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
# ---> 13     X_train, X_valid = df3data[train_idx], df3data[test_idx]
#      14     y_train, y_valid = df3data[train_idx], df3data[test_idx]
#      15
#
# D:\Anaconda3\envs\xai\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# D:\Anaconda3\envs\xai\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# D:\Anaconda3\envs\xai\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# D:\Anaconda3\envs\xai\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Int64Index([    0,     1,     2,     4,     5,     6,     7,     8,     9,\n               10,\n            ...\n            17409, 17410, 17412, 17413, 17414, 17415, 17416, 17417, 17418,\n            17419],\n           dtype='int64', length=14516)] are in the [columns]"

# %% [markdown]
# ### shap

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
class shap.Explainer(model, masker=None, link=CPUDispatcher(<function identity>), algorithm='auto', output_names=None, feature_names=None, linearize_link=True, **kwargs)

# %%
# 设置解释器
explainer = shap.Explainer(model=MLP, data=train_data)

# %%
# 解释测试集中的单个预测
shap_values = explainer(train_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48592/420889570.py in <module>
#       1 # 解释测试集中的单个预测
# ----> 2 shap_values = explainer(train_data)
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\explainers\_permutation.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      60                     return super().__call__(
#      61                         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
# ---> 62                         batch_size=batch_size, outputs=outputs, silent=silent
#      63                     )
#      64             Permutation.__call__.__doc__ = self.__class__.__call__.__doc__
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\explainers\_permutation.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      74         return super().__call__(
#      75             *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
# ---> 76             outputs=outputs, silent=silent
#      77         )
#      78
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\explainers\_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     258             row_result = self.explain_row(
#     259                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
# --> 260                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     261             )
#     262             values.append(row_result.get("values", None))
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\explainers\_permutation.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#      82
#      83         # build a masked version of the model for the current input sample
# ---> 84         fm = MaskedModel(self.model, self.masker, self.link, self.linearize_link, *row_args)
#      85
#      86         # by default we run 10 permutations forward and backward
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\utils\_masked_model.py in __init__(self, model, masker, link, linearize_link, *args)
#      46         else:
#      47             self._masker_rows = None# # just assuming...
# ---> 48             self._masker_cols = sum(np.prod(a.shape) for a in self.args)
#      49
#      50         self._linearizing_weights = None
#
# D:\Anaconda3\envs\xai\lib\site-packages\shap\utils\_masked_model.py in <genexpr>(.0)
#      46         else:
#      47             self._masker_rows = None# # just assuming...
# ---> 48             self._masker_cols = sum(np.prod(a.shape) for a in self.args)
#      49
#      50         self._linearizing_weights = None
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
shap.plots.bar(shap_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48592/2348624746.py in <module>
# ----> 1 shap.plots.bar(shap_values)
#
# NameError: name 'shap_values' is not defined
